# %%
#imports
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from random import random
from random import seed
from math import exp

# %%
# No. of data points
n_samples = 200

# No. of features (dimensions of the data)
n_features = 4

# No. of redundent features (linear combinations of other features)
n_redundant = 1

# No. of classes
n_classes = 2

# %%
X, y = make_classification(n_samples=n_samples, n_features=n_features,
                                            n_redundant=n_redundant, n_classes=n_classes)
df = pd.DataFrame(X, columns=['feature1', 'feature2', 'feature3', 'feature4'])
df['label'] = y
df.head()
# Out:
#    feature1  feature2  feature3  feature4  label
# 0 -0.656134  0.310525  0.936812  0.543369      1
# 1 -1.226402 -1.667919  1.468561 -0.191813      0
# 2 -0.810019  0.688634  1.194878 -0.438608      1
# 3  0.146412 -0.089074 -0.211529 -0.297711      1
# 4 -0.736674 -1.371241  0.835730  0.711622      0

# %%
df.to_csv("dataset1.csv")

# %%
#reading the dataset 
df=pd.read_csv('dataset1.csv',index_col=0)
df.head()
# Out:
#    feature1  feature2  feature3  feature4  label
# 0 -0.656134  0.310525  0.936812  0.543369      1
# 1 -1.226402 -1.667919  1.468561 -0.191813      0
# 2 -0.810019  0.688634  1.194878 -0.438608      1
# 3  0.146412 -0.089074 -0.211529 -0.297711      1
# 4 -0.736674 -1.371241  0.835730  0.711622      0

# %%
#initializing the network for weights
def initialize_network(n_inputs, n_hidden, n_outputs):
    network=list()
    hidden_layer = [{'weights':[random() for i in range(n_inputs + 1)]} for i in range(n_hidden)]
    network.append(hidden_layer)
    output_layer = [{'weights':[random() for i in range(n_hidden + 1)]} for i in range(n_outputs)]
    network.append(output_layer)
    return network

# %%
#activation function
def activate(weights, inputs):
    activation=weights[-1]
    for i in range(len(weights)-1):
        activation+=weights[i]*inputs[i]
    return activation

def transfer(activation):
    return 1.0 / (1.0 + exp(-activation))

# %%
#forward propogation
def forward_propagate(network,raw):
    inputs=raw
    for layer in network:
        new_inputs=[]
        for neuron in layer:
            activation=activate(neuron['weights'], inputs)
            neuron['output']=transfer(activation)
            new_inputs.append(neuron['output'])
        inputs=new_inputs
    return inputs


def transfer_derivative(output):
    return output * (1.0 - output)

# %%
#backward propogation to learn
def backward_propagate_error(network, expected):
    for i in reversed(range(len(network))):
        layer = network[i]
        errors = list()
        if i != len(network)-1:
            for j in range(len(layer)):
                error = 0.0
                for neuron in network[i + 1]:
                    error += (neuron['weights'][j] * neuron['delta'])
                errors.append(error)
        else:
            for j in range(len(layer)):
                neuron = layer[j]
                errors.append(expected[j] - neuron['output'])
        for j in range(len(layer)):
            neuron = layer[j]
            neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])

# %%
#update weights on training
def update_weights(network, row, l_rate):
    for i in range(len(network)):
        inputs=row[:-1]
        if i!=0:
            inputs=[neuron['output'] for neuron in network[i-1]]
        for neuron in network[i]:
            for j in range(len(inputs)):
                neuron['weights'][j]+=l_rate*neuron['delta']*inputs[j]
            neuron['weights'][-1]+=l_rate*neuron['delta']

# %%
#training the network
def train_network(network, train, l_rate, n_epoch, n_outputs):
    for epoch in range(n_epoch):
        sum_error = 0
        for row in train:
            outputs = forward_propagate(network, row)
            expected = [0 for i in range(n_outputs)]
            expected[int(row[-1])] = 1
            sum_error += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
            backward_propagate_error(network, expected)
            update_weights(network, row, l_rate)
        print('>epoch=%d, lrate=%.3f, error=%.3f' % (epoch, l_rate, sum_error))

# %%
#predicting function
def predict(network, row):
    outputs = forward_propagate(network, row)
    return outputs.index(max(outputs))

# %%
dataset=np.array(df[:])
dataset
# Out:
# array([[-6.56134419e-01,  3.10525422e-01,  9.36811952e-01,
#          5.43368517e-01,  1.00000000e+00],
#        [-1.22640243e+00, -1.66791931e+00,  1.46856143e+00,
#         -1.91812638e-01,  0.00000000e+00],
#        [-8.10018954e-01,  6.88634460e-01,  1.19487769e+00,
#         -4.38607737e-01,  1.00000000e+00],
#        [ 1.46412313e-01, -8.90743943e-02, -2.11529102e-01,
#         -2.97710878e-01,  1.00000000e+00],
#        [-7.36673787e-01, -1.37124111e+00,  8.35730071e-01,
#          7.11621637e-01,  0.00000000e+00],
#        [-8.59332781e-01,  1.99248882e+00,  1.42616166e+00,
#         -4.13147185e-01,  1.00000000e+00],
#        [-3.83900652e-01,  1.62377194e+00,  7.29296923e-01,
#          6.08694716e-01,  1.00000000e+00],
#        [-5.19391474e-01,  1.57499439e+00,  9.08563224e-01,
#         -7.57117509e-02,  1.00000000e+00],
#        [-1.27461570e+00, -1.36649422e+00,  1.57240139e+00,
#          7.02798302e-02,  0.00000000e+00],
#        [-1.54174510e+00, -1.43307716e+00,  1.92955402e+00,
#          1.19139270e+00,  0.00000000e+00],
#        [-8.52679430e-01,  6.26602790e-02,  1.17460777e+00,
#         -7.35474226e-01,  1.00000000e+00],
#        [ 1.46889823e+00, -1.83430992e+00, -2.24036782e+00,
#         -2.09438029e+00,  0.00000000e+00],
#        [-1.81853661e+00, -4.96182012e-01,  2.42599735e+00,
#         -3.60825511e-01,  0.00000000e+00],
#        [ 1.21221103e+00,  1.49193469e+00, -1.47125258e+00,
#          3.73755438e-01,  1.00000000e+00],
#        [-7.15608763e-01,  2.28681747e+00,  1.26647905e+00,
#         -3.78967329e-01,  1.00000000e+00],
#        [-1.04425478e+00, -6.31323535e-01,  1.34955631e+00,
#          1.97802749e+00,  0.00000000e+00],
#        [-7.24075427e-01, -1.74745325e+00,  7.71226890e-01,
#          1.88276090e+00,  0.00000000e+00],
#        [-1.55071098e+00, -3.34355090e-01,  2.07985784e+00,
#          7.53817054e-01,  0.00000000e+00],
#        [-1.60056007e+00, -1.72838382e+00,  1.97293128e+00,
#         -2.28422598e+00,  0.00000000e+00],
#        [-7.19979490e-02, -1.05160272e+00, -3.35999249e-02,
#         -1.20102851e+00,  0.00000000e+00],
#        [-2.21951375e-02, -6.24393753e-01, -4.80744352e-02,
#         -6.28575931e-01,  0.00000000e+00],
#        [ 5.09389384e-01,  3.72879226e-01, -6.50160133e-01,
#          1.39645291e+00,  1.00000000e+00],
#        [ 1.10813380e+00,  1.35069536e+00, -1.34658626e+00,
#          1.51280006e+00,  1.00000000e+00],
#        [-6.27912490e-01,  4.72074330e-01,  9.18491276e-01,
#          3.71504047e-01,  1.00000000e+00],
#        [ 1.40366885e+00, -1.27601770e+00, -2.08097348e+00,
#          6.03156560e-02,  0.00000000e+00],
#        [ 5.34636399e-01, -3.02958774e-01, -7.69613552e-01,
#         -8.70159457e-01,  0.00000000e+00],
#        [-7.89173111e-02, -8.01882674e-01,  7.24101417e-03,
#         -1.15287029e+00,  0.00000000e+00],
#        [-1.19717554e+00, -6.86571790e-01,  1.55185935e+00,
#          1.00708136e+00,  0.00000000e+00],
#        [-3.39720488e-01,  1.19921776e-01,  4.79911367e-01,
#         -1.74570115e+00,  1.00000000e+00],
#        [-4.24028912e-01,  1.83255805e+00,  8.10435505e-01,
#          1.53141182e+00,  1.00000000e+00],
#        [ 7.98091327e-01,  5.02423439e-01, -1.02892083e+00,
#          4.90228628e-01,  1.00000000e+00],
#        [-6.17347381e-01, -3.49392700e-01,  8.00831553e-01,
#         -7.14077145e-01,  0.00000000e+00],
#        [ 7.65590591e-01,  2.96719779e-01, -1.01029268e+00,
#         -2.04999858e-01,  1.00000000e+00],
#        [-8.05227775e-01,  4.34971933e-01,  1.15645347e+00,
#          3.17877361e-01,  1.00000000e+00],
#        [ 6.15599670e-01,  9.10335570e-01, -7.27967236e-01,
#         -1.16160835e+00,  1.00000000e+00],
#        [-1.09611255e+00, -9.81898379e-01,  1.37647043e+00,
#          7.75965589e-01,  0.00000000e+00],
#        [ 1.85297001e-01, -1.70042807e+00, -4.67174750e-01,
#         -1.01597609e-01,  0.00000000e+00],
#        [ 1.66942907e+00, -2.13652388e+00, -2.55272555e+00,
#         -9.45822709e-01,  0.00000000e+00],
#        [-3.67286183e-01,  1.05165184e+00,  6.34685944e-01,
#         -2.76716136e-01,  1.00000000e+00],
#        [-3.14412468e-01, -1.17388305e+00,  2.82737493e-01,
#         -4.33836384e-01,  0.00000000e+00],
#        [-5.17321437e-01, -9.23967829e-01,  5.91778820e-01,
#          4.02713488e-01,  0.00000000e+00],
#        [ 5.85779431e-01, -1.66262118e+00, -1.01041179e+00,
#         -1.12045162e+00,  0.00000000e+00],
#        [-3.05429795e-01, -1.34114435e+00,  2.49432824e-01,
#          1.15009846e-03,  0.00000000e+00],
#        [ 4.17302847e-01,  8.23738181e-01, -4.67513849e-01,
#          2.21726641e-01,  0.00000000e+00],
#        [-1.08136309e-02,  1.45259200e+00,  1.97289856e-01,
#          2.11149818e+00,  1.00000000e+00],
#        [-6.44643725e-01,  4.61737997e-01,  9.40086321e-01,
#         -1.06287021e+00,  1.00000000e+00],
#        [-7.17025639e-01,  8.18718513e-01,  1.08397621e+00,
#          9.15689994e-01,  1.00000000e+00],
#        [ 5.81203170e-01, -7.58036180e-03, -7.96222393e-01,
#          7.88349075e-01,  1.00000000e+00],
#        [ 9.33265650e-01,  1.33765169e+00, -1.10894995e+00,
#          1.55084173e+00,  1.00000000e+00],
#        [ 1.09706603e+00, -1.50914524e+00, -1.69073218e+00,
#         -7.72501952e-01,  0.00000000e+00],
#        [ 2.54702802e-01, -1.14341023e+00, -4.92164091e-01,
#          9.39514624e-01,  0.00000000e+00],
#        [-1.28868558e+00, -1.84843464e+00,  1.53110585e+00,
#          2.96695118e-01,  0.00000000e+00],
#        [-5.54831192e-01,  1.10049863e+00,  8.97443692e-01,
#          3.77301722e-01,  1.00000000e+00],
#        [ 8.77967671e-01,  1.29603235e+00, -1.03851356e+00,
#          1.13181682e+00,  1.00000000e+00],
#        [-3.93572735e-01,  1.57270997e+00,  7.36116333e-01,
#         -7.10620093e-01,  1.00000000e+00],
#        [-1.27700419e+00, -1.30155496e+00,  1.58382810e+00,
#          3.08941639e+00,  0.00000000e+00],
#        [-6.78489548e-01,  1.42510786e+00,  1.10742910e+00,
#          1.37442389e+00,  1.00000000e+00],
#        [-3.48527511e-01, -8.47180506e-01,  3.70462275e-01,
#         -6.33829934e-01,  0.00000000e+00],
#        [ 7.32898875e-01,  8.04150556e-01, -9.01810040e-01,
#          4.61345224e-01,  1.00000000e+00],
#        [ 3.49205081e-01,  2.20116876e-01, -4.50169244e-01,
#          1.83469447e+00,  1.00000000e+00],
#        [ 1.11193514e+00,  2.06143902e+00, -1.26249489e+00,
#          1.93413181e+00,  1.00000000e+00],
#        [-1.44848069e+00, -2.30302343e-01,  1.95304687e+00,
#          1.09492146e+00,  0.00000000e+00],
#        [ 1.40220857e+00,  1.97176744e+00, -1.67094661e+00,
#         -1.21607933e+00,  1.00000000e+00],
#        [ 1.39256154e+00, -1.77993636e+00, -2.12908394e+00,
#         -1.03657460e-01,  0.00000000e+00],
#        [-6.79195647e-01, -8.58640840e-01,  8.21481238e-01,
#         -1.18630436e+00,  0.00000000e+00],
#        [ 5.19820015e-01,  3.83898872e-01, -6.63048109e-01,
#         -2.29132067e+00,  1.00000000e+00],
#        [ 7.49544369e-01,  5.09448227e-01, -9.61610665e-01,
#          2.08810660e+00,  1.00000000e+00],
#        [-6.83280958e-01,  2.00777842e+00,  1.18718788e+00,
#         -6.02607114e-01,  1.00000000e+00],
#        [ 4.62772007e-02, -8.62933391e-01, -1.71734717e-01,
#         -2.71334700e+00,  0.00000000e+00],
#        [-8.50517538e-01, -2.88576840e-02,  1.16015194e+00,
#         -2.48551111e-01,  1.00000000e+00],
#        [-7.57857128e-01,  3.21458811e-01,  1.07737444e+00,
#         -6.83726938e-01,  1.00000000e+00],
#        [ 7.31207145e-01, -1.77843019e+00, -1.22395239e+00,
#          7.89048433e-02,  0.00000000e+00],
#        [-3.25394249e-01,  2.10334740e+00,  7.09492099e-01,
#          6.49829922e-01,  1.00000000e+00],
#        [-2.84629977e-01, -1.87831891e+00,  1.53485272e-01,
#          5.15198644e-02,  0.00000000e+00],
#        [-6.58178355e-01, -1.62144986e+00,  6.96888997e-01,
#         -9.22033933e-02,  0.00000000e+00],
#        [-5.43769278e-01,  1.67320726e-01,  7.65069619e-01,
#          5.62014337e-01,  1.00000000e+00],
#        [ 6.97184686e-01, -1.38514229e+00, -1.12798898e+00,
#         -2.25003855e+00,  0.00000000e+00],
#        [-1.42694038e+00, -1.02378161e+00,  1.82388578e+00,
#         -4.83190553e-01,  0.00000000e+00],
#        [-6.45330702e-01,  1.72565702e+00,  1.09981617e+00,
#         -2.53518403e-01,  1.00000000e+00],
#        [-5.69573600e-01,  2.61552539e+00,  1.10795322e+00,
#         -2.14153793e-01,  1.00000000e+00],
#        [-6.46387813e-01,  1.60725518e+00,  1.08638746e+00,
#         -2.85519144e-01,  1.00000000e+00],
#        [-3.56847186e-01, -8.71930792e-01,  3.78736775e-01,
#          1.50208087e+00,  0.00000000e+00],
#        [-7.72749091e-01, -1.16518640e+00,  9.10979770e-01,
#          7.50182745e-01,  0.00000000e+00],
#        [ 7.89173328e-01,  8.09555536e-01, -9.78132275e-01,
#          1.56560805e+00,  1.00000000e+00],
#        [-8.16540071e-01, -1.52723088e+00,  9.25414996e-01,
#          2.04672859e-01,  0.00000000e+00],
#        [-2.89221043e-01,  6.44560273e-01,  4.76724000e-01,
#          5.63156983e-01,  1.00000000e+00],
#        [-4.77885904e-01,  1.12616828e+00,  7.95383117e-01,
#         -6.70769382e-01,  1.00000000e+00],
#        [ 2.87731675e-02, -1.79764713e+00, -2.65214477e-01,
#         -7.46920849e-01,  0.00000000e+00],
#        [ 1.18759196e+00,  1.48029933e+00, -1.43902767e+00,
#          3.17021611e-02,  1.00000000e+00],
#        [-9.73184632e-01, -2.12890330e-01,  1.30487883e+00,
#          3.42587554e-01,  1.00000000e+00],
#        [ 8.67194281e-01,  8.60747824e-01, -1.07845822e+00,
#          8.83176506e-01,  1.00000000e+00],
#        [ 3.69549357e-01, -4.54918224e-01, -5.62813293e-01,
#         -5.41518830e-02,  0.00000000e+00],
#        [-4.83278862e-01,  6.93923643e-01,  7.48458234e-01,
#         -7.08929845e-02,  1.00000000e+00],
#        [-1.55523933e+00, -1.11890278e+00,  1.98748904e+00,
#         -3.71231356e-01,  0.00000000e+00],
#        [ 1.10251388e+00,  1.24608302e+00, -1.35203919e+00,
#         -1.18065512e+00,  1.00000000e+00],
#        [-5.68978093e-01,  1.22877471e+00,  9.32916834e-01,
#          4.09392002e-01,  1.00000000e+00],
#        [-3.40503966e-01, -7.53989494e-01,  3.71191384e-01,
#          1.14725156e+00,  0.00000000e+00],
#        [ 6.65616443e-01,  5.29326706e-01, -8.44273284e-01,
#         -2.54433462e+00,  0.00000000e+00],
#        [-2.39213656e-01, -1.48055851e+00,  1.41313162e-01,
#          1.45782220e+00,  0.00000000e+00],
#        [ 1.89921537e+00,  7.39789090e-01, -2.50578639e+00,
#          9.79802398e-01,  0.00000000e+00],
#        [ 2.66997939e-01, -2.89543626e-01, -4.01713973e-01,
#         -1.52190717e+00,  1.00000000e+00],
#        [ 1.44932783e+00,  2.78545822e+00, -1.63319433e+00,
#         -1.00659077e+00,  1.00000000e+00],
#        [ 1.68151847e+00, -1.45945823e+00, -2.48420595e+00,
#          9.85061499e-01,  0.00000000e+00],
#        [ 1.58382069e-01, -5.68036256e-01, -2.88080900e-01,
#         -1.49393042e+00,  0.00000000e+00],
#        [-5.97828442e-01, -1.41771418e+00,  6.39907108e-01,
#          9.92662644e-01,  0.00000000e+00],
#        [-8.36034698e-01, -1.97562981e+00,  8.95756152e-01,
#         -9.35267456e-01,  0.00000000e+00],
#        [-3.83853763e-01, -2.08692524e+00,  2.63047020e-01,
#         -9.87396552e-01,  0.00000000e+00],
#        [ 8.74395582e-01,  1.58982493e+00, -9.96715788e-01,
#          6.09853609e-01,  1.00000000e+00],
#        [ 1.00386509e+00, -1.68739419e+00, -1.58559772e+00,
#         -4.51901670e-01,  0.00000000e+00],
#        [-6.91237575e-01,  1.62991406e-01,  9.66309059e-01,
#         -6.44740368e-01,  0.00000000e+00],
#        [-6.15706208e-01,  2.71995195e+00,  1.18419666e+00,
#          8.68997297e-01,  1.00000000e+00],
#        [ 8.87805813e-01,  1.03038570e+00, -1.08534922e+00,
#          1.79977300e-01,  1.00000000e+00],
#        [-5.63428177e-01, -1.56744246e+00,  5.74025845e-01,
#          1.11133108e+00,  0.00000000e+00],
#        [-8.70392201e-01,  2.33850216e+00,  1.48476512e+00,
#         -2.79121316e-01,  1.00000000e+00],
#        [ 1.61653899e+00,  2.66968781e+00, -1.87653673e+00,
#          1.12965914e+00,  1.00000000e+00],
#        [ 1.00446851e+00, -1.20959288e+00, -1.52639581e+00,
#         -9.80196603e-01,  0.00000000e+00],
#        [-1.89199755e+00, -3.59215470e-01,  2.54372271e+00,
#          1.02021659e+00,  0.00000000e+00],
#        [ 1.14366933e+00,  1.68931632e+00, -1.35266819e+00,
#         -3.47104163e-01,  1.00000000e+00],
#        [-9.85863520e-02, -8.55451869e-01,  2.74244381e-02,
#         -1.40045247e+00,  0.00000000e+00],
#        [ 1.10811840e-01, -8.56912409e-01, -2.59282113e-01,
#          7.77776882e-01,  1.00000000e+00],
#        [-1.15511358e+00,  3.18959516e-01,  1.62063311e+00,
#          9.31958938e-01,  0.00000000e+00],
#        [ 1.06206788e+00,  1.46703957e+00, -1.26893682e+00,
#         -4.24948046e-02,  1.00000000e+00],
#        [-6.58444380e-01,  5.52026794e-02,  9.07895768e-01,
#          1.33054058e+00,  0.00000000e+00],
#        [ 4.36153259e-01, -6.53838263e-01, -6.78939437e-01,
#         -8.71913918e-01,  0.00000000e+00],
#        [-4.50418105e-01, -4.40567846e-01,  5.60964823e-01,
#         -7.72862434e-01,  0.00000000e+00],
#        [ 4.70862947e-01, -6.31329219e-01, -7.23605408e-01,
#         -1.60905148e+00,  0.00000000e+00],
#        [ 1.37827867e+00, -2.44282364e+00, -2.19282091e+00,
#          1.62364864e+00,  0.00000000e+00],
#        [ 3.62752939e-01, -1.81382852e+00, -7.24237517e-01,
#         -5.87641623e-01,  0.00000000e+00],
#        [-7.02727700e-01,  2.26770172e+00,  1.24645211e+00,
#         -2.12699527e-01,  1.00000000e+00],
#        [ 8.59994720e-01,  1.03008328e+00, -1.04733283e+00,
#         -8.45769166e-02,  1.00000000e+00],
#        [-1.39305751e+00, -6.49924835e-01,  1.82449201e+00,
#          8.42840891e-01,  0.00000000e+00],
#        [ 6.55891629e-01, -5.85799189e-01, -9.71063188e-01,
#         -1.87446495e+00,  0.00000000e+00],
#        [-1.34974115e+00, -7.85094111e-01,  1.74823980e+00,
#          7.48152768e-01,  0.00000000e+00],
#        [ 8.53420650e-01,  9.03354817e-01, -1.05425869e+00,
#          9.14289141e-01,  1.00000000e+00],
#        [ 9.92833695e-02, -1.03294361e+00, -2.65622829e-01,
#          1.80087654e+00,  0.00000000e+00],
#        [ 1.03569848e+00,  1.84190805e+00, -1.18575931e+00,
#         -7.77529355e-01,  1.00000000e+00],
#        [ 1.40870295e+00, -7.83731569e-01, -2.02601438e+00,
#         -1.21494645e+00,  0.00000000e+00],
#        [ 9.77277947e-01,  1.55124985e+00, -1.14233775e+00,
#          1.30819784e+00,  1.00000000e+00],
#        [-6.87339793e-01,  1.45127526e+00,  1.12282653e+00,
#         -5.40437734e-01,  1.00000000e+00],
#        [-5.65365901e-01,  7.71809336e-01,  8.70564314e-01,
#         -7.70089165e-01,  1.00000000e+00],
#        [ 1.09965985e+00, -1.72742113e+00, -1.72170400e+00,
#         -6.48137974e-01,  0.00000000e+00],
#        [-8.81602196e-01,  1.08849874e-01,  1.21998620e+00,
#         -1.51974074e+00,  0.00000000e+00],
#        [ 1.80392410e-01, -6.46403144e-01, -3.28043480e-01,
#         -7.91726927e-01,  0.00000000e+00],
#        [ 1.05879411e+00,  1.43467698e+00, -1.26852308e+00,
#         -7.07998850e-01,  1.00000000e+00],
#        [-1.75861796e-01, -8.13289058e-01,  1.38458762e-01,
#         -1.51567863e-01,  0.00000000e+00],
#        [ 3.15563306e-01, -1.67589659e+00, -6.42338358e-01,
#         -1.08066683e+00,  0.00000000e+00],
#        [ 6.06672720e-01, -1.58958433e-01, -8.50090875e-01,
#          1.65647664e-01,  1.00000000e+00],
#        [-1.08345275e+00,  1.07597573e-01,  1.49602437e+00,
#          1.04255660e+00,  1.00000000e+00],
#        [ 1.35468675e+00,  2.07285822e+00, -1.59322137e+00,
#         -1.36149829e+00,  1.00000000e+00],
#        [-4.04753497e-01,  8.09793943e-01,  6.55567784e-01,
#          1.63057381e+00,  1.00000000e+00],
#        [-4.30350298e-02, -2.57096794e+00, -2.64112673e-01,
#          2.86423892e-01,  0.00000000e+00],
#        [ 1.01655882e+00,  9.04897175e-01, -1.27728960e+00,
#         -4.69987051e-01,  1.00000000e+00],
#        [ 1.02229281e+00, -6.59293152e-01, -1.48164933e+00,
#          8.32100464e-01,  0.00000000e+00],
#        [-4.28290999e-01,  5.82576376e-01,  6.59228535e-01,
#          5.18612968e-01,  1.00000000e+00],
#        [ 3.07007459e-01, -8.15355326e-01, -5.22518933e-01,
#         -1.65024299e+00,  0.00000000e+00],
#        [ 1.10608505e+00, -7.17973539e-01, -1.60367585e+00,
#          7.68456828e-01,  0.00000000e+00],
#        [-8.25337022e-01,  2.36404101e-01,  1.15902263e+00,
#         -2.81605269e-01,  1.00000000e+00],
#        [ 4.89245985e-01, -6.61689845e-01, -7.52573522e-01,
#          2.02700951e+00,  1.00000000e+00],
#        [ 1.53546916e+00,  2.98060138e+00, -1.72654655e+00,
#          7.60855335e-01,  1.00000000e+00],
#        [ 1.18897682e+00,  1.40988521e+00, -1.44976892e+00,
#         -9.61103655e-01,  1.00000000e+00],
#        [ 6.42927288e-01,  5.71120278e-01, -8.07976685e-01,
#          1.33298525e+00,  1.00000000e+00],
#        [ 6.43947974e-01, -1.05860779e+00, -1.01412081e+00,
#         -4.17054657e-01,  0.00000000e+00],
#        [ 3.12742354e-01,  1.59765623e-01, -4.07858788e-01,
#          9.31376718e-01,  1.00000000e+00],
#        [-9.07632548e-02, -6.88625148e-01,  3.76788920e-02,
#         -1.23753492e+00,  0.00000000e+00],
#        [ 5.15039902e-01, -5.45871665e-01, -7.73317195e-01,
#         -1.15482172e+00,  0.00000000e+00],
#        [ 8.76998136e-01,  9.35992342e-01, -1.08241981e+00,
#         -8.01261504e-02,  1.00000000e+00],
#        [-3.92094491e-01,  1.66863084e+00,  7.46144446e-01,
#          1.33966967e-01,  1.00000000e+00],
#        [-4.07516469e-01,  1.56915218e-01,  5.77325340e-01,
#          8.03518881e-01,  1.00000000e+00],
#        [ 4.25644425e-02, -1.21541140e+00, -2.10937332e-01,
#          8.05393381e-01,  0.00000000e+00],
#        [-3.20488564e-01,  2.93890470e+00,  8.07753077e-01,
#         -1.85424542e-01,  1.00000000e+00],
#        [-8.36490882e-01, -2.53703760e-01,  1.11271096e+00,
#          4.46642222e-01,  0.00000000e+00],
#        [ 1.24418767e+00,  2.17366922e+00, -1.42935844e+00,
#         -1.02329994e+00,  1.00000000e+00],
#        [-4.54170027e-01,  5.05192279e-01,  6.84917253e-01,
#          5.31628821e-01,  1.00000000e+00],
#        [ 7.13304781e-01,  1.05331883e+00, -8.43695373e-01,
#         -9.36289723e-01,  1.00000000e+00],
#        [-9.79623542e-01,  2.37855499e+00,  1.63926015e+00,
#         -8.93594510e-01,  1.00000000e+00],
#        [-6.71043100e-01,  1.39466367e+00,  1.09341521e+00,
#         -3.39258141e-01,  1.00000000e+00],
#        [ 6.35093801e-01,  7.02015717e-01, -7.80813215e-01,
#          1.11115920e+00,  1.00000000e+00],
#        [ 4.61772766e-01, -1.65973362e+00, -8.40368615e-01,
#          2.30382067e+00,  0.00000000e+00],
#        [-1.81671951e+00, -9.05476276e-02,  2.47447203e+00,
#          1.68582863e+00,  0.00000000e+00],
#        [ 1.75010166e+00,  2.63920151e+00, -2.06312286e+00,
#          1.07409971e+00,  1.00000000e+00],
#        [ 9.06680731e-01, -1.36376064e+00, -1.41195970e+00,
#         -1.67787897e-01,  0.00000000e+00],
#        [-1.11691606e-01,  1.05857999e+00,  2.85822000e-01,
#         -2.30218841e-01,  1.00000000e+00],
#        [ 5.92000686e-01, -1.43972475e+00, -9.90921305e-01,
#         -4.76442239e-01,  0.00000000e+00],
#        [ 1.57536105e+00,  2.04721424e+00, -1.89839544e+00,
#          1.65075230e-02,  1.00000000e+00],
#        [-7.41278443e-01,  1.53207755e+00,  1.20678312e+00,
#          7.94882612e-01,  1.00000000e+00],
#        [-8.25302263e-01,  7.81207485e-01,  1.22742032e+00,
#          8.89294495e-01,  1.00000000e+00],
#        [-3.63441346e-01, -1.94748619e+00,  2.52634503e-01,
#         -2.47231437e+00,  1.00000000e+00],
#        [ 1.37120596e+00, -1.17114895e+00, -2.02337899e+00,
#         -1.02088022e+00,  0.00000000e+00],
#        [ 7.58926348e-01,  5.91013079e-01, -9.64200953e-01,
#         -1.66259062e+00,  1.00000000e+00],
#        [-9.96263742e-01,  1.73026110e-02,  1.36537817e+00,
#          1.14465210e+00,  1.00000000e+00],
#        [ 5.21822518e-02, -1.94418899e+00, -3.15656003e-01,
#          4.33064193e-01,  0.00000000e+00],
#        [ 9.52013409e-01,  1.62661531e+00, -1.09829948e+00,
#         -1.80066782e-01,  1.00000000e+00],
#        [-2.53922786e+00, -4.23111079e-01,  3.42131140e+00,
#          3.34266516e-02,  0.00000000e+00],
#        [-8.85137977e-01, -1.08579945e+00,  1.07473698e+00,
#         -1.25881354e-01,  0.00000000e+00],
#        [-1.48404725e+00,  1.42615216e-01,  2.04856391e+00,
#          2.91149671e-01,  0.00000000e+00],
#        [-5.94621273e-01,  1.08937007e-01,  8.27316340e-01,
#         -2.55714250e-01,  0.00000000e+00],
#        [-6.67033908e-01, -1.76639932e+00,  6.90795773e-01,
#         -7.32622276e-01,  0.00000000e+00],
#        [ 4.97500194e-01, -6.25930844e-01, -7.59375386e-01,
#          8.09160755e-01,  0.00000000e+00],
#        [ 8.40056371e-01,  1.72122810e+00, -9.33220304e-01,
#          1.17539411e+00,  1.00000000e+00],
#        [ 2.85000038e-01, -5.52162822e-01, -4.59340166e-01,
#          4.17073518e-01,  0.00000000e+00]])

# %%
n_inputs = len(dataset[0]) - 1
n_outputs = len(set([row[-1] for row in dataset]))
print(n_inputs,n_outputs)
# Out:
# 4 2

# %%
#splitting into test and train datset
train_dataset=dataset[:150]
test_dataset=dataset[150:]

# %%
#feeding the datset into the network
network=initialize_network(n_inputs,1,n_outputs)
train_network(network, train_dataset, 0.5, 100, n_outputs)
# Out:
# >epoch=0, lrate=0.500, error=67.556
# >epoch=1, lrate=0.500, error=38.709
# >epoch=2, lrate=0.500, error=27.563
# >epoch=3, lrate=0.500, error=23.651
# >epoch=4, lrate=0.500, error=21.861
# >epoch=5, lrate=0.500, error=20.889
# >epoch=6, lrate=0.500, error=20.288
# >epoch=7, lrate=0.500, error=19.873
# >epoch=8, lrate=0.500, error=19.558
# >epoch=9, lrate=0.500, error=19.302
# >epoch=10, lrate=0.500, error=19.086
# >epoch=11, lrate=0.500, error=18.902
# >epoch=12, lrate=0.500, error=18.743
# >epoch=13, lrate=0.500, error=18.607
# >epoch=14, lrate=0.500, error=18.490
# >epoch=15, lrate=0.500, error=18.388
# >epoch=16, lrate=0.500, error=18.300
# >epoch=17, lrate=0.500, error=18.223
# >epoch=18, lrate=0.500, error=18.156
# >epoch=19, lrate=0.500, error=18.097
# >epoch=20, lrate=0.500, error=18.045
# >epoch=21, lrate=0.500, error=17.999
# >epoch=22, lrate=0.500, error=17.958
# >epoch=23, lrate=0.500, error=17.922
# >epoch=24, lrate=0.500, error=17.889
# >epoch=25, lrate=0.500, error=17.859
# >epoch=26, lrate=0.500, error=17.832
# >epoch=27, lrate=0.500, error=17.808
# >epoch=28, lrate=0.500, error=17.785
# >epoch=29, lrate=0.500, error=17.764
# >epoch=30, lrate=0.500, error=17.745
# >epoch=31, lrate=0.500, error=17.727
# >epoch=32, lrate=0.500, error=17.710
# >epoch=33, lrate=0.500, error=17.694
# >epoch=34, lrate=0.500, error=17.679
# >epoch=35, lrate=0.500, error=17.665
# >epoch=36, lrate=0.500, error=17.652
# >epoch=37, lrate=0.500, error=17.640
# >epoch=38, lrate=0.500, error=17.628
# >epoch=39, lrate=0.500, error=17.617
# >epoch=40, lrate=0.500, error=17.606
# >epoch=41, lrate=0.500, error=17.596
# >epoch=42, lrate=0.500, error=17.586
# >epoch=43, lrate=0.500, error=17.577
# >epoch=44, lrate=0.500, error=17.568
# >epoch=45, lrate=0.500, error=17.560
# >epoch=46, lrate=0.500, error=17.552
# >epoch=47, lrate=0.500, error=17.544
# >epoch=48, lrate=0.500, error=17.537
# >epoch=49, lrate=0.500, error=17.530
# >epoch=50, lrate=0.500, error=17.523
# >epoch=51, lrate=0.500, error=17.517
# >epoch=52, lrate=0.500, error=17.511
# >epoch=53, lrate=0.500, error=17.505
# >epoch=54, lrate=0.500, error=17.499
# >epoch=55, lrate=0.500, error=17.493
# >epoch=56, lrate=0.500, error=17.488
# >epoch=57, lrate=0.500, error=17.483
# >epoch=58, lrate=0.500, error=17.478
# >epoch=59, lrate=0.500, error=17.473
# >epoch=60, lrate=0.500, error=17.469
# >epoch=61, lrate=0.500, error=17.464
# >epoch=62, lrate=0.500, error=17.460
# >epoch=63, lrate=0.500, error=17.456
# >epoch=64, lrate=0.500, error=17.452
# >epoch=65, lrate=0.500, error=17.448
# >epoch=66, lrate=0.500, error=17.444
# >epoch=67, lrate=0.500, error=17.440
# >epoch=68, lrate=0.500, error=17.437
# >epoch=69, lrate=0.500, error=17.433
# >epoch=70, lrate=0.500, error=17.430
# >epoch=71, lrate=0.500, error=17.427
# >epoch=72, lrate=0.500, error=17.423
# >epoch=73, lrate=0.500, error=17.420
# >epoch=74, lrate=0.500, error=17.417
# >epoch=75, lrate=0.500, error=17.414
# >epoch=76, lrate=0.500, error=17.412
# >epoch=77, lrate=0.500, error=17.409
# >epoch=78, lrate=0.500, error=17.406
# >epoch=79, lrate=0.500, error=17.403
# >epoch=80, lrate=0.500, error=17.401
# >epoch=81, lrate=0.500, error=17.398
# >epoch=82, lrate=0.500, error=17.396
# >epoch=83, lrate=0.500, error=17.393
# >epoch=84, lrate=0.500, error=17.391
# >epoch=85, lrate=0.500, error=17.388
# >epoch=86, lrate=0.500, error=17.386
# >epoch=87, lrate=0.500, error=17.384
# >epoch=88, lrate=0.500, error=17.381
# >epoch=89, lrate=0.500, error=17.379
# >epoch=90, lrate=0.500, error=17.377
# >epoch=91, lrate=0.500, error=17.375
# >epoch=92, lrate=0.500, error=17.373
# >epoch=93, lrate=0.500, error=17.371
# >epoch=94, lrate=0.500, error=17.369
# >epoch=95, lrate=0.500, error=17.367
# >epoch=96, lrate=0.500, error=17.365
# >epoch=97, lrate=0.500, error=17.363
# >epoch=98, lrate=0.500, error=17.361
# >epoch=99, lrate=0.500, error=17.359

# %%
#learned weights of the network
for layer in network:
    print(layer)
# Out:
# [{'weights': [1.337920763536887, 9.213781919823663, 0.8977625016455786, -0.7476764984890443, 2.8825284014801036], 'output': 0.999896065659801, 'delta': 8.261176901039936e-06}]
# [{'weights': [-6.481174919546664, 4.055439882951116], 'output': 0.0817407835609989, 'delta': -0.0061354000990732575}, {'weights': [6.481027755942583, -4.05532362808749], 'output': 0.9182568723353219, 'delta': 0.006135736334185702}]

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#applying on training dataset
y_train=[]
pred=[]
for row in train_dataset:
    prediction = predict(network, row)
    y_train.append(int(row[-1]))
    pred.append(prediction)

# %%
print("Accuracy: ",accuracy_score(y_train,pred))
print("Confusion Matrix: ",confusion_matrix(y_train,pred))
print("Precision: ",precision_score(y_train, pred))
print("recall: ",recall_score(y_train, pred))
# Out:
# Accuracy:  0.94
# Confusion Matrix:  [[69  8]
#  [ 1 72]]
# Precision:  0.9
# recall:  0.9863013698630136

# %%
#applying on testing dataset
y_test=[]
pred=[]
for row in test_dataset:
    prediction = predict(network, row)
    y_test.append(row[-1])
    pred.append(prediction)

# %%
print("Accuracy: ",accuracy_score(y_test,pred))
print("Confusion Matrix: ",confusion_matrix(y_test,pred))
print("Precision: ",precision_score(y_test, pred))
print("recall: ",recall_score(y_test, pred))
# Out:
# Accuracy:  0.9
# Confusion Matrix:  [[19  3]
#  [ 2 26]]
# Precision:  0.896551724137931
# recall:  0.9285714285714286
